# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
netflix = pd.read_csv('viewings.csv')

# %%
netflix
# Out:
#                       Start Time Profile Name         Duration  \
# 0      2023-05-04 12:42:00-04:00     faridatt  0 days 00:00:10
# 1      2023-05-03 17:50:00-04:00     faridatt  0 days 00:00:12
# 2      2023-05-03 17:49:00-04:00     faridatt  0 days 00:00:10
# 3      2023-05-03 17:49:00-04:00     faridatt  0 days 00:00:12
# 4      2023-05-03 17:47:00-04:00     faridatt  0 days 00:00:35
# ...                          ...          ...              ...
# 10623  2014-12-21 22:41:00-05:00     faridatt  0 days 00:04:29
# 10624  2014-12-21 21:37:00-05:00     faridatt  0 days 00:42:27
# 10625  2014-12-21 20:54:00-05:00     faridatt  0 days 00:42:18
# 10626  2014-12-21 20:09:00-05:00     faridatt  0 days 00:44:29
# 10627  2014-12-21 18:15:00-05:00     faridatt  0 days 01:33:31
#
#                             Attributes  \
# 0      Autoplayed: user action: None;
# 1      Autoplayed: user action: None;
# 2      Autoplayed: user action: None;
# 3      Autoplayed: user action: None;
# ...

# %%
show_titles = list(netflix['Show Title'])

# %%
top_views = pd.Series(show_titles).value_counts().nlargest(10)

# %%
n = len(top_views)
s = np.arange(n)

colors = plt.get_cmap('viridis')

plt.figure(figsize=(10,5))
plt.bar(top_views.index, top_views.values,
       color=colors(s/n))

plt.ylabel("Freq", fontsize=12)
plt.xlabel("Show Titles", fontsize=12)
plt.xticks(rotation=30, ha='right', fontsize=11)

plt.title('My Top 10 Shows Based on Viewing Activity', fontsize=16)


plt.show()

# %%
genre = list(netflix['Genre'])

# %%
top_genre = pd.Series(genre).value_counts().nlargest(10)

# %%
n = len(top_genre)
s = np.arange(n)

colors = plt.get_cmap('viridis')

plt.figure(figsize=(10,5))
plt.bar(top_genre.index, top_genre.values,
       color=colors(s/n))

plt.ylabel("Freq", fontsize=12)
plt.xlabel("Genre", fontsize=12)
plt.xticks(rotation=30, ha='right', fontsize=11)

plt.title('My Top 10 Genres Based on Viewing Activity', fontsize=16)


plt.show()
